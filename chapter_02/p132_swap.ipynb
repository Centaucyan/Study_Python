# %%
#. p132

str_data_1 = input("첫번째 문장 입력: ")
str_data_2 = input("두번째 문장 입력: ")

print("=== 1st 문장 + 2nd 문장 ===")
print(str_data_1, "", str_data_2)

temp = str_data_1
str_data_1 = str_data_2
str_data_2 = temp

print("=== 1st 문장 + 2nd 문장 ===")
print(str_data_1, "", str_data_2)
# Out:
# === 1st 문장 + 2nd 문장 ===
# abc  def
# === 1st 문장 + 2nd 문장 ===
# def  abc
